# %% [markdown]
# # Try simple case of non-bifurcation for fixed control and 51 trials

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")


from stabnode.utils import set_global_seed
from data.budworm import simulate_trials, budworm_steady_states


seed = 1234
set_global_seed(seed=seed)
device = 'cpu'

# %% [markdown]
# ## Generate multiple trajectories for $k=5.34$ (trial 0, one steady state case)

# %%
k = 5.34569072482332

# %%
xs = []
ts = []

x0s = np.linspace(0.1,10,51)
for x0 in x0s:
    budworm_trial =simulate_trials([k],x0, dt=0.1,r=0.56,eps=1e-3,buffer=1e-1,t_max=400,n_points=501, show_progress=False)
    xs.append(budworm_trial.x_vals[0])
    ts.append(budworm_trial.t_vals[0])

# %%
# expected steady states for fixed k and r
steady_states = budworm_steady_states(k,r=0.56)

plt.figure(figsize=(10,5))
for ti, xi in zip(ts, xs):
    plt.plot(ti,xi)
for x_steady_state in steady_states:
    plt.axhline(x_steady_state, linestyle='--',label=rf"steady state. $x_s$={x_steady_state:.3f}")
plt.xlabel("t")
plt.ylabel("x")
plt.legend()
plt.show()

# %% [markdown]
# ## preprocess data and create data loader

# %%
import torch
from sklearn.preprocessing import MinMaxScaler
from stabnode.data import TrialsDataset

# %%
scaler = MinMaxScaler()
scaler.fit(np.concatenate(xs).reshape(-1,1))

xs_scaled = [scaler.transform(xi.reshape(-1,1)).reshape(-1) for xi in xs]

# %%
xs_torch = [torch.tensor(xi,dtype=torch.float32,device=device) for xi in xs_scaled]
ts_torch = [torch.tensor(ti,dtype=torch.float32,device=device) for ti in ts]

# %%
train_dataset = TrialsDataset(x_trials=xs_torch, t_trials=ts_torch)
train_loader = torch.utils.data.DataLoader(train_dataset,shuffle=False,batch_size=1,num_workers=0)

# %% [markdown]
# # Create and train model

# %%
import torch.nn as nn
from stabnode.node import GeluSigmoid, FeluSigmoid, StabNODE, model_trainer

# %%
# create new classes for constant f and g

f = FeluSigmoid(
    dim_in=1,
    dim_out=1,
    hidden_dim=8,
    lower_bound=-0.5,
    upper_bound=-0.1
)

g = GeluSigmoid(
    dim_in=1+1, # input is x dim + k dim
    dim_out=1,
    hidden_dim=8,
    lower_bound=-5,
    upper_bound=1.1  
)

model = StabNODE(f,g).to(device)

# %%
n_epochs = 200
lr = 1e-3
show_progress = True
solve_method = 'tsit5'
loss_criteria = nn.MSELoss()
opt = torch.optim.Adam(list(f.parameters())+list(g.parameters()), lr = lr)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(opt,mode='min',factor=0.1,patience=10)

model, log_history = model_trainer(
    model=model,
    opt=opt,
    loss_criteria=loss_criteria,
    train_loader=train_loader,
    n_epochs=n_epochs,
    control=lambda t: torch.tensor(k,dtype=torch.float32,device=device).unsqueeze(0),
    min_improvement=1e-6,
    patience=30,
    solve_method='tsit5',
    save_folder=None,
    show_progress=True,
    scheduler=scheduler,
    print_every=10,
    effective_batch_size=1,
    _precision=7,
)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch 0: Loss: 0.0042647. time = 16.6156020s. lr = 0.0010000
# Epoch 1: Loss: 0.0022305. time = 15.0812650s. lr = 0.0010000
# Epoch 2: Loss: 0.0017983. time = 15.7111161s. lr = 0.0010000
# Epoch 3: Loss: 0.0015425. time = 16.4663970s. lr = 0.0010000
# Epoch 4: Loss: 0.0013258. time = 16.1227291s. lr = 0.0010000
# Epoch 5: Loss: 0.0011811. time = 15.4175429s. lr = 0.0010000
# Epoch 10: Loss: 0.0009696. time = 14.9363179s. lr = 0.0010000
# Epoch 20: Loss: 0.0007096. time = 14.6077850s. lr = 0.0010000
# Epoch 30: Loss: 0.0004725. time = 13.8956170s. lr = 0.0010000
# Epoch 40: Loss: 0.0003490. time = 13.4211349s. lr = 0.0010000
# Epoch 50: Loss: 0.0003027. time = 12.9402580s. lr = 0.0010000
# Epoch 60: Loss: 0.0002544. time = 12.8023310s. lr = 0.0010000
# Epoch 70: Loss: 0.0002124. time = 12.6890049s. lr = 0.0010000
# Epoch 80: Loss: 0.0001894. time = 12.9136500s. lr = 0.0010000
# Epoch 90: Loss: 0.0001747. time = 12.8840630s. lr = 0.0010000
# Epoch 100: Loss: 0.0001650. time = 12.6510453s. lr = 0.0010000
# Epoch 110: Loss: 0.0001584. time = 12.7474868s. lr = 0.0010000
# Epoch 120: Loss: 0.0001539. time = 12.8866632s. lr = 0.0010000
# Epoch 130: Loss: 0.0001507. time = 12.6724379s. lr = 0.0010000
# Epoch 140: Loss: 0.0001484. time = 12.9361911s. lr = 0.0010000
# Epoch 150: Loss: 0.0001468. time = 12.7561100s. lr = 0.0010000
# Epoch 160: Loss: 0.0001455. time = 12.7677071s. lr = 0.0010000
# Epoch 170: Loss: 0.0001445. time = 12.8248911s. lr = 0.0010000
# Epoch 180: Loss: 0.0001436. time = 12.8503799s. lr = 0.0010000
# Epoch 190: Loss: 0.0001429. time = 12.7985220s. lr = 0.0010000

# %%
print(log_history["stopping_criteria"])
# Out:
# max-epochs

# %% [markdown]
# # Look at results

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(12,5))
ax1.set_title("Training Loss")
ax1.plot(log_history["losses"])
ax1.set_yscale('log')
ax1.set_xlabel("epochs")
ax1.set_ylabel("Loss (logscale)")

ax2.set_title("Learning Rate")
ax2.plot(log_history['lr_hist'])
ax2.set_xlabel('epochs')
ax2.set_ylabel("lr")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Learned trajectories via solving `stabnode` model with `torchode.solve_ivp`

# %%
from torchode import solve_ivp
from tqdm.auto import tqdm

# %%
g_eval = model.g.eval()
f_eval = model.f.eval()

model_eval = StabNODE(f_eval,g_eval)

# %%
scaled_steady_states = scaler.transform(np.array(budworm_steady_states(k,r=0.56)).reshape(-1,1)).reshape(-1)

# %%
cols = 5
rows = int(np.ceil(len(train_dataset)/cols))

fig, axs = plt.subplots(rows, cols,figsize=(5*cols,4*rows))

axs = axs.flatten()

control_func = lambda t: torch.tensor(k,dtype=torch.float32,device=device).unsqueeze(0)
with torch.no_grad():
    for idx in tqdm(range(len(train_dataset))):
        ax = axs[idx]
        xi, ti, x0i = train_dataset[idx]

        sol = solve_ivp(
            f=lambda t, x: model_eval(t, x, control_func),
            y0=x0i.reshape(-1,1),
            t_eval=ti,
            method=solve_method
        )

        rel_l2_err = np.linalg.norm(sol.ys.squeeze() - xi)/np.linalg.norm(xi)

        ax.plot(ti,xi,label='true',color='black')
        ax.plot(sol.ts.squeeze(),sol.ys.squeeze(),label="pred", linestyle='--', color='blue',alpha=0.4,lw=4)
        ax.set_ylim(0,1)
        ax.set_title(rf"$x_0$={x0i:.3f}, $L_2$ err = {rel_l2_err:.3f}", family='serif',size=20)
        ax.legend(prop={'family':'serif','size':20})

        for idx,xsi in enumerate(scaled_steady_states):
            label = rf"steady state. $x_s=${xsi:.3f}"
            color = 'black'
            if idx ==1:
                label = rf"unsteady state. $x_s=${xsi:.3f}"
                color = 'red'

            ax.axhline(
                xsi,
                xmin=0,
                c=color,
                linestyle="--",
                label=label,
                zorder=2
            )

    for idx in range(len(train_dataset), rows*cols):
        fig.delaxes(axs[idx])

plt.suptitle(f"Epochs {n_epochs}", size=20)
plt.tight_layout(rect=[0, 0, 1, 0.96]) 
plt.show()
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]

# %% [markdown]
# # Learned vs True $g$ and $f$

# %% [markdown]
# How does scaling pass through model learning
#
# Let $S$ be an affine transformation, *e.g.,* MinMax or Standard scaler.
#
# $$
# y= S(x) = ax+b, \quad \text{with} \quad x = S^{-1}(y)
# $$
#
# Then we have
#
# $$
# \begin{align}
# \dot{y} &= \frac{dx}{dt}S(x)\\
#  &= S'(x) \dot x\\
#  &= S'(x) f(x)(x - g(x,u))\\
#  &= f(S^{-1}(y)) (S(x) - S(g(x,u))), \quad \text{since } S' \text{ is constant}\\
#  &= \tilde f(y) (y - \tilde g(y,u))
# \end{align}
# $$
#
# Where we define relation
#
# $$
# \tilde f(y) \triangleq f(S^{-1}(y)) \quad \text{and} \quad \tilde g(y,u) \triangleq S(g(S^{-1}(y),u))
# $$

# %%
from data.budworm import g_true, f_true

# %%
x_lin = np.linspace(0,1,101)
with torch.no_grad():
    x_lin_torch = torch.tensor(x_lin, dtype=torch.float32)
    f_pred = [f_eval(xi.reshape(-1,1)).reshape(-1) for xi in x_lin_torch]
    f_pred = torch.cat(f_pred)
    
    k_torch = torch.tensor(k,dtype=torch.float32).reshape(-1,1)
    g_pred =torch.cat([g_eval(torch.tensor([[xi]],dtype=torch.float32),k_torch).reshape(-1) for xi in x_lin_torch])

x_lin_unscaled = scaler.inverse_transform(x_lin.reshape(-1,1)).squeeze()

f_true_arr =  f_true(x_lin_unscaled)
g_true_arr = scaler.transform(g_true(x_lin_unscaled, k, r=0.56).reshape(-1,1)).squeeze()

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(10,5))

ax1.plot(x_lin, g_true_arr,label='true',c='black')
ax1.plot(x_lin_torch, g_pred, label='pred', linestyle='--', c='blue', alpha=0.5, lw=3)
ax1.plot(x_lin, x_lin, c='black', linestyle='--',alpha=0.5,label=r"$g(x)=x$")
ax1.set_title(r"$g$")
ax1.set_xlabel(r"$x$")
ax1.set_ylabel(r"$g(x)$")
# ax1.set_ylim(-0.1,1)
ax1.legend()

ax2.plot(x_lin, f_true_arr, label='true', c='black')
ax2.plot(x_lin_torch, f_pred, label='pred',linestyle='--',c='blue',lw=3,alpha=0.5)
ax2.set_xlabel(r"$x$")
ax2.set_ylabel(r"$f(x)$")
ax2.set_title(r"$f$")
ax2.legend()
plt.suptitle(r"Learned $g$ and $f$"+f"\nk={k:.4f}", family='serif', size=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Modify f for tight bounds and twice as many `elu` layers in $g$ (`GeluSigmoid2`)

# %%
import torch.nn as nn
from stabnode.node import GeluSigmoid2, FeluSigmoid, StabNODE, model_trainer
from data.budworm import f_true

# %%
x_lin = np.linspace(0,1,101)
x_lin_unscaled = scaler.inverse_transform(x_lin.reshape(-1,1)).reshape(-1)
f_true_arr =  f_true(x_lin_unscaled)

# %%
# create new classes for constant f and g

buffer = 0.05
f_true_mean = np.mean(f_true_arr)

f = FeluSigmoid(
    dim_in=1,
    dim_out=1,
    hidden_dim=8,
    lower_bound=f_true_mean - buffer,
    upper_bound=f_true_mean + buffer
)

# sigmoid2 has two non-linear layers
g = GeluSigmoid2(
    dim_in=1+1, # input is x dim + k dim
    dim_out=1, 
    hidden_dim=8,
    lower_bound=-5,
    upper_bound=1.1  
)

model = StabNODE(f,g).to(device)

# %%
n_epochs = 500
lr = 1e-3
show_progress = True
solve_method = 'tsit5'
loss_criteria = nn.MSELoss()
opt = torch.optim.Adam(list(f.parameters())+list(g.parameters()), lr = lr)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(opt,mode='min',factor=0.1,patience=10)

model, log_history = model_trainer(
    model=model,
    opt=opt,
    loss_criteria=loss_criteria,
    train_loader=train_loader,
    n_epochs=n_epochs,
    control=lambda t: torch.tensor(k,dtype=torch.float32,device=device).unsqueeze(0),
    min_improvement=1e-6,
    patience=30,
    solve_method='tsit5',
    save_folder=None,
    show_progress=True,
    scheduler=scheduler,
    print_every=20,
    effective_batch_size=1,
    _precision=7,
)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch 0: Loss: 1.6600809. time = 17.5882549s. lr = 0.0010000
# Epoch 1: Loss: 0.1135215. time = 19.0469301s. lr = 0.0010000
# Epoch 2: Loss: 0.0080202. time = 18.4491150s. lr = 0.0010000
# Epoch 3: Loss: 0.0021333. time = 17.8854139s. lr = 0.0010000
# Epoch 4: Loss: 0.0020370. time = 18.1246541s. lr = 0.0010000
# Epoch 5: Loss: 0.0020669. time = 17.7962351s. lr = 0.0010000
# Epoch 20: Loss: 0.0020077. time = 17.4435961s. lr = 0.0001000
# Epoch 40: Loss: 0.0019986. time = 17.9704630s. lr = 0.0001000
# Epoch 60: Loss: 0.0019910. time = 18.0778928s. lr = 0.0001000
# Epoch 80: Loss: 0.0019779. time = 17.8510382s. lr = 0.0001000
# Epoch 100: Loss: 0.0019551. time = 17.8947051s. lr = 0.0001000
# Epoch 120: Loss: 0.0019111. time = 17.6035802s. lr = 0.0001000
# Epoch 140: Loss: 0.0018356. time = 17.3103728s. lr = 0.0001000
# Epoch 160: Loss: 0.0017401. time = 16.8690181s. lr = 0.0001000
# Epoch 180: Loss: 0.0016454. time = 15.3966322s. lr = 0.0001000
# Epoch 200: Loss: 0.0015614. time = 16.6167548s. lr = 0.0001000
# Epoch 220: Loss: 0.0014898. time = 17.3469470s. lr = 0.0001000
# Epoch 240: Loss: 0.0014295. time = 17.3651128s. lr = 0.0001000
# Epoch 260: Loss: 0.0013787. time = 17.5965860s. lr = 0.0001000
# Epoch 280: Loss: 0.0013358. time = 17.9083829s. lr = 0.0001000
# Epoch 300: Loss: 0.0012993. time = 17.1521509s. lr = 0.0001000
# Epoch 320: Loss: 0.0012680. time = 17.8569210s. lr = 0.0001000
# Epoch 340: Loss: 0.0012407. time = 18.0519691s. lr = 0.0001000
# Epoch 360: Loss: 0.0012166. time = 17.7819710s. lr = 0.0001000
# Epoch 380: Loss: 0.0011948. time = 17.7145429s. lr = 0.0001000
# Epoch 400: Loss: 0.0011747. time = 17.5486610s. lr = 0.0001000
# Epoch 420: Loss: 0.0011553. time = 17.4029701s. lr = 0.0001000
# Epoch 440: Loss: 0.0011354. time = 17.8174720s. lr = 0.0001000
# Epoch 460: Loss: 0.0011127. time = 17.4884501s. lr = 0.0001000
# Epoch 480: Loss: 0.0010851. time = 16.8637550s. lr = 0.0001000

# %%
print(log_history["stopping_criteria"])
# Out:
# max-epochs

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(12,5))
ax1.set_title("Training Loss")
ax1.plot(log_history["losses"])
ax1.set_yscale('log')
ax1.set_xlabel("epochs")
ax1.set_ylabel("Loss (logscale)")

ax2.set_title("Learning Rate")
ax2.plot(log_history['lr_hist'])
ax2.set_xlabel('epochs')
ax2.set_ylabel("lr")

plt.tight_layout()
plt.show()

# %%
print(np.sum(log_history["times"])/60)
# Out:
# 145.5509808341662

# %% [markdown]
# ## save model!

# %%
from stabnode.node import _save_model_opt_cpu, _create_save_paths

# %%
folder = f"big_exp_epochs_{n_epochs}_lr_{n_epochs}"
model_opt_path, log_path = _create_save_paths(folder)
model_opt_path
# Out:
# 'big_exp_epochs_500_lr_500/model_opt_states.pt'

# %%
_save_model_opt_cpu(
    model=model,
    opt=opt,
    epoch=log_history["best_model_epoch"],
    loss = log_history["losses"][-1],
    save_path = model_opt_path,
    scheduler = scheduler
)

# %% [markdown]
# ## Look at results

# %%
from torchode import solve_ivp
from tqdm.auto import tqdm

g_eval = model.g.eval()
f_eval = model.f.eval()

model_eval = StabNODE(f_eval,g_eval)

scaled_steady_states = scaler.transform(np.array(budworm_steady_states(k,r=0.56)).reshape(-1,1)).reshape(-1)

# %%
cols = 5
rows = int(np.ceil(len(train_dataset)/cols))

fig, axs = plt.subplots(rows, cols,figsize=(5*cols,4*rows))

axs = axs.flatten()

control_func = lambda t: torch.tensor(k,dtype=torch.float32,device=device).unsqueeze(0)
with torch.no_grad():
    for idx in tqdm(range(len(train_dataset))):
        ax = axs[idx]
        xi, ti, x0i = train_dataset[idx]

        sol = solve_ivp(
            f=lambda t, x: model_eval(t, x, control_func),
            y0=x0i.reshape(-1,1),
            t_eval=ti,
            method=solve_method
        )

        rel_l2_err = np.linalg.norm(sol.ys.squeeze() - xi)/np.linalg.norm(xi)

        ax.plot(ti,xi,label='true',color='black')
        ax.plot(sol.ts.squeeze(),sol.ys.squeeze(),label="pred", linestyle='--', color='blue',alpha=0.4,lw=4)
        ax.set_ylim(0,1)
        ax.set_title(rf"$x_0$={x0i:.3f}, $L_2$ err = {rel_l2_err:.3f}", family='serif',size=20)
        ax.legend(prop={'family':'serif','size':20})

        for idx,xsi in enumerate(scaled_steady_states):
            label = rf"steady state. $x_s=${xsi:.3f}"
            color = 'black'
            if idx ==1:
                label = rf"unsteady state. $x_s=${xsi:.3f}"
                color = 'red'

            ax.axhline(
                xsi,
                xmin=0,
                c=color,
                linestyle="--",
                label=label,
                zorder=2
            )

    for idx in range(len(train_dataset), rows*cols):
        fig.delaxes(axs[idx])

plt.suptitle(f"Epochs {n_epochs}", size=20)
plt.tight_layout(rect=[0, 0, 1, 0.96]) 
plt.show()
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]

# %% [markdown]
# ## f and g

# %%
from data.budworm import g_true, f_true

# %%
x_lin = np.linspace(0,1,101)
with torch.no_grad():
    x_lin_torch = torch.tensor(x_lin, dtype=torch.float32)
    f_pred = [f_eval(xi.reshape(-1,1)).reshape(-1) for xi in x_lin_torch]
    f_pred = torch.cat(f_pred)
    
    k_torch = torch.tensor(k,dtype=torch.float32).reshape(-1,1)
    g_pred =torch.cat([g_eval(torch.tensor([[xi]],dtype=torch.float32),k_torch).reshape(-1) for xi in x_lin_torch])

x_lin_unscaled = scaler.inverse_transform(x_lin.reshape(-1,1)).squeeze()

f_true_arr =  f_true(x_lin_unscaled)
g_true_arr = scaler.transform(g_true(x_lin_unscaled, k, r=0.56).reshape(-1,1)).squeeze()

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(10,5))

ax1.plot(x_lin, g_true_arr,label='true',c='black')
ax1.plot(x_lin_torch, g_pred, label='pred', linestyle='--', c='blue', alpha=0.5, lw=3)
ax1.plot(x_lin, x_lin, c='black', linestyle='--',alpha=0.5,label=r"$g(x)=x$")
ax1.set_title(r"$g$")
ax1.set_xlabel(r"$x$")
ax1.set_ylabel(r"$g(x)$")
# ax1.set_ylim(-0.1,1)
ax1.legend()

ax2.plot(x_lin, f_true_arr, label='true', c='black')
ax2.plot(x_lin_torch, f_pred, label='pred',linestyle='--',c='blue',lw=3,alpha=0.5)
ax2.set_xlabel(r"$x$")
ax2.set_ylabel(r"$f(x)$")
ax2.set_title(r"$f$")
ax2.legend()
plt.suptitle(r"Learned $g$ and $f$"+f"\nk={k:.4f}", family='serif', size=20)
plt.tight_layout()
plt.show()

# %%
f_eval.args
# Out:
# {'dim_in': 1,
#  'dim_out': 1,
#  'hidden_dim': 8,
#  'lower_bound': -0.2811816952021074,
#  'upper_bound': -0.18118169520210742}
