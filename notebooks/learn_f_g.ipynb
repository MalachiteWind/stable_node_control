# %%
import time

import torch
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
from scipy.integrate import solve_ivp
from sklearn.preprocessing import StandardScaler, MinMaxScaler

print(torch.cuda.is_available())
print(torch.cuda.get_device_name() if torch.cuda.is_available() else "no gpu")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# False
# no gpu
# device(type='cpu')

# %%
seed = 1234
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# # Load simple ODE

# %%
def hysteresis_ode(t,x,lam):
    return lam+x-x**3

def simulate_branch(lam_values, x0):
    x_vals = []
    x_curr = x0
    for lam in tqdm(lam_values):
        sol = solve_ivp(hysteresis_ode, [0, 50], [x_curr], args=(lam,), t_eval=[50])
        x_curr = sol.y[0, -1]  # final value
        x_vals.append(x_curr)
    return np.array(x_vals)

# %%
lam_start = -1 
lam_end = 1

lam_up = np.linspace(lam_start, lam_end, 250)
lam_down = np.linspace(lam_end, lam_start, 250)

# %%
x0=-1
x_increase = simulate_branch(lam_up, x0)
x_decrease = simulate_branch(lam_down,x_increase[-1])
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
#   0%|          | 0/250 [00:00<?, ?it/s]

# %%
fig, ax = plt.subplots(1,1, figsize = (6,5))

ax.plot(lam_up, x_increase, c='blue', label=r'increasing $\lambda$')
ax.plot(lam_down, x_decrease, c='red', linestyle="--", label=r'decreasing $\lambda$')
ax.grid(True)
ax.set_xlabel(r"$\lambda$")
ax.set_ylabel(r"$x(t = \infty)$",size = 15)
ax.set_title("Steady states of "+r"$\dot{x} = \lambda + x - x^3$")
ax.legend()
plt.show()

# %%
X = np.hstack((x_increase, x_decrease))
X = np.hstack((X,X))

lam_vals  = np.hstack((lam_up,lam_down))
lam_vals = np.hstack((lam_vals,lam_vals))

scaler = StandardScaler()
scaler = MinMaxScaler(feature_range=(-1,1))
X.shape
X = scaler.fit_transform(X.reshape(-1,1))

t_train = np.arange(0,len(X),5)
X_train = X[t_train]
lam_train = lam_vals[t_train]

# %%
X.max()
# Out:
# 1.0

# %%
fig, ax = plt.subplots(2,1,figsize=(10,5))
ax[0].plot(X)
ax[0].scatter(t_train,X_train)
ax[1].plot(lam_vals)
ax[1].scatter(t_train,lam_train)
plt.show()

# %% [markdown]
# # Neuro ODE approach

# %%
import numpy as np

import torch 
import torch.nn as nn
from torchdiffeq import odeint

# %%
def lam_func(t):
    lam_vals = np.hstack((lam_up,lam_down))
    idx = int(t) % len(lam_vals)
    return torch.tensor(lam_vals[idx], dtype=torch.float32, device=device)

# %%
class FTerm(nn.Module):
    def __init__(self,dim_in, dim_out, hidden_dim = 4):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(dim_in, hidden_dim),
            nn.Tanh(),
            nn.Linear(hidden_dim, dim_out),
            nn.Tanh(),
        )
    def forward(self,x):
        return - torch.exp(self.network(x))


class GTerm(nn.Module):
    def __init__(self, dim_in, dim_out, hidden_dim = 4):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(dim_in, hidden_dim),
            nn.Tanh(),
            nn.Linear(hidden_dim, dim_out),
            nn.Tanh(),
        )

    def forward(self, x, u):
        xu = torch.cat([x,u],dim=-1)
        return self.network(xu)


class ODEModel(nn.Module):
    def __init__(self,f,g):
        super().__init__()
        self.f = f
        self.g = g

    def forward(self, t, state, u_func):
        x = state
        u = u_func(t).unsqueeze(0).unsqueeze(1)
        fx = self.f(x)
        gx = self.g(x,u)
        return fx*(x-gx)

# %%
x_true = torch.tensor(X, dtype=torch.float32,device=device)
x0 = torch.tensor([[x_true[0]]],requires_grad = True, device=device)
dim_in = 1
dim_out = 1
f = FTerm(dim_in, dim_out).to(device)
g = GTerm(2, dim_out).to(device)

ode_model = ODEModel(f,g).to(device)

# %%
t_span = torch.arange(1000,dtype=torch.float32,device=device)

# %%
lam_func(t_span[0])
# Out:
# tensor(-1.)

# %%
t0 = time.time()
# non-adaptive method is much faster
# see what is being used in neuromancer
method='rk4'
x_pred = odeint(lambda t, x: ode_model(t,x,lam_func),x0,t_span, method =method)
print(time.time()-t0)
# Out:
# 0.8892266750335693

# %%
x_pred.squeeze().shape, X.squeeze().shape
# Out:
# (torch.Size([1000]), (1000,))

# %%
fig, ax = plt.subplots(1,1, figsize=(8,5))

ax.plot(x_pred.squeeze().detach().cpu().numpy(), linestyle='--',c='red')
ax.plot(x_true.squeeze().detach().cpu().numpy(),)
plt.show()

# %%
x_true.squeeze().max()
# Out:
# tensor(1.)

# %%
# about 46-1hr
loss_criteria = nn.MSELoss()
opt = torch.optim.Adam(list(f.parameters())+list(g.parameters()), lr=1e-2)
n_epochs = 200

for epoch in tqdm(range(n_epochs)):
    t1 = time.time()
    opt.zero_grad()
    x_pred = odeint(lambda t, x: ode_model(t,x,lam_func), x0, t_span, method='rk4')
    loss = loss_criteria(x_pred.squeeze(), x_true.squeeze())
    loss.backward()
    opt.step()
    t2 = time.time()
    print(f"Epoch {epoch}: Loss = {loss.item():.4f}, time = {t2-t1:.4f} s.")
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch 0: Loss = 0.8387, time = 1.9140 s.
# Epoch 1: Loss = 0.8123, time = 1.9616 s.
# Epoch 2: Loss = 0.7872, time = 2.0156 s.
# Epoch 3: Loss = 0.7637, time = 2.0448 s.
# Epoch 4: Loss = 0.7418, time = 2.2134 s.
# Epoch 5: Loss = 0.7216, time = 2.0669 s.
# Epoch 6: Loss = 0.7033, time = 2.0719 s.
# Epoch 7: Loss = 0.6865, time = 2.0740 s.
# Epoch 8: Loss = 0.6712, time = 2.2228 s.
# Epoch 9: Loss = 0.6571, time = 2.0690 s.
# Epoch 10: Loss = 0.6439, time = 2.0652 s.
# Epoch 11: Loss = 0.6313, time = 2.0768 s.
# Epoch 12: Loss = 0.6191, time = 2.0646 s.
# Epoch 13: Loss = 0.6071, time = 2.2186 s.
# Epoch 14: Loss = 0.5950, time = 2.0685 s.
# Epoch 15: Loss = 0.5827, time = 2.0725 s.
# Epoch 16: Loss = 0.5701, time = 2.0633 s.
# Epoch 17: Loss = 0.5571, time = 2.0689 s.
# Epoch 18: Loss = 0.5435, time = 2.2171 s.
# Epoch 19: Loss = 0.5295, time = 2.0723 s.
# Epoch 20: Loss = 0.5149, time = 2.0623 s.
# Epoch 21: Loss = 0.5000, time = 2.0701 s.
# Epoch 22: Loss = 0.4846, time = 2.2119 s.
# Epoch 23: Loss = 0.4690, time = 2.0701 s.
# Epoch 24: Loss = 0.4533, time = 2.0682 s.
# Epoch 25: Loss = 0.4375, time = 2.0703 s.
# Epoch 26: Loss = 0.4217, time = 2.0641 s.
# Epoch 27: Loss = 0.4062, time = 2.2131 s.
# Epoch 28: Loss = 0.3909, time = 2.0660 s.
# Epoch 29: Loss = 0.3760, time = 2.0684 s.
# Epoch 30: Loss = 0.3616, time = 2.0744 s.
# Epoch 31: Loss = 0.3476, time = 2.2115 s.
# Epoch 32: Loss = 0.3342, time = 2.0706 s.
# Epoch 33: Loss = 0.3213, time = 2.0653 s.
# Epoch 34: Loss = 0.3090, time = 2.0821 s.
# Epoch 35: Loss = 0.2973, time = 2.0806 s.
# Epoch 36: Loss = 0.2862, time = 2.2135 s.
# Epoch 37: Loss = 0.2760, time = 2.0599 s.
# Epoch 38: Loss = 0.2665, time = 2.0639 s.
# Epoch 39: Loss = 0.2580, time = 2.0555 s.
# Epoch 40: Loss = 0.2505, time = 2.0611 s.
# Epoch 41: Loss = 0.2441, time = 2.2070 s.
# Epoch 42: Loss = 0.2387, time = 2.0594 s.
# Epoch 43: Loss = 0.2342, time = 2.0585 s.
# Epoch 44: Loss = 0.2308, time = 2.0598 s.
# Epoch 45: Loss = 0.2281, time = 2.0561 s.
# Epoch 46: Loss = 0.2261, time = 2.1986 s.
# Epoch 47: Loss = 0.2246, time = 2.0530 s.
# Epoch 48: Loss = 0.2236, time = 2.0533 s.
# Epoch 49: Loss = 0.2228, time = 2.0559 s.
# Epoch 50: Loss = 0.2222, time = 2.2053 s.
# Epoch 51: Loss = 0.2217, time = 2.0613 s.
# Epoch 52: Loss = 0.2212, time = 2.0566 s.
# Epoch 53: Loss = 0.2206, time = 2.0554 s.
# Epoch 54: Loss = 0.2201, time = 2.0546 s.
# Epoch 55: Loss = 0.2194, time = 2.1957 s.
# Epoch 56: Loss = 0.2186, time = 2.0549 s.
# Epoch 57: Loss = 0.2177, time = 2.0489 s.
# Epoch 58: Loss = 0.2166, time = 2.0474 s.
# Epoch 59: Loss = 0.2153, time = 2.2027 s.
# Epoch 60: Loss = 0.2137, time = 2.0530 s.
# Epoch 61: Loss = 0.2118, time = 2.0503 s.
# Epoch 62: Loss = 0.2095, time = 2.0497 s.
# Epoch 63: Loss = 0.2067, time = 2.0531 s.
# Epoch 64: Loss = 0.2033, time = 2.1883 s.
# Epoch 65: Loss = 0.1990, time = 2.0566 s.
# Epoch 66: Loss = 0.1938, time = 2.0526 s.
# Epoch 67: Loss = 0.1874, time = 2.0517 s.
# Epoch 68: Loss = 0.1795, time = 2.0460 s.
# Epoch 69: Loss = 0.1700, time = 2.1967 s.
# Epoch 70: Loss = 0.1586, time = 2.0501 s.
# Epoch 71: Loss = 0.1451, time = 2.0466 s.
# Epoch 72: Loss = 0.1294, time = 2.0537 s.
# Epoch 73: Loss = 0.1116, time = 2.2010 s.
# Epoch 74: Loss = 0.0921, time = 2.0604 s.
# Epoch 75: Loss = 0.0716, time = 2.0448 s.
# Epoch 76: Loss = 0.0506, time = 2.0567 s.
# Epoch 77: Loss = 0.0289, time = 2.0465 s.
# Epoch 78: Loss = 0.0110, time = 2.1965 s.
# Epoch 79: Loss = 0.0176, time = 2.0448 s.
# Epoch 80: Loss = 0.0367, time = 2.0502 s.
# Epoch 81: Loss = 0.0504, time = 2.0496 s.
# Epoch 82: Loss = 0.0559, time = 2.1941 s.
# Epoch 83: Loss = 0.0533, time = 2.0492 s.
# Epoch 84: Loss = 0.0442, time = 2.0589 s.
# Epoch 85: Loss = 0.0313, time = 2.0580 s.
# Epoch 86: Loss = 0.0188, time = 2.0527 s.
# Epoch 87: Loss = 0.0126, time = 2.1907 s.
# Epoch 88: Loss = 0.0125, time = 2.0522 s.
# Epoch 89: Loss = 0.0153, time = 2.0494 s.
# Epoch 90: Loss = 0.0202, time = 2.0506 s.
# Epoch 91: Loss = 0.0247, time = 2.1970 s.
# Epoch 92: Loss = 0.0268, time = 2.0544 s.
# Epoch 93: Loss = 0.0261, time = 2.0540 s.
# Epoch 94: Loss = 0.0229, time = 2.0537 s.
# Epoch 95: Loss = 0.0183, time = 2.0518 s.
# Epoch 96: Loss = 0.0137, time = 2.1980 s.
# Epoch 97: Loss = 0.0108, time = 2.0489 s.
# Epoch 98: Loss = 0.0101, time = 2.0447 s.
# Epoch 99: Loss = 0.0111, time = 2.0515 s.
# Epoch 100: Loss = 0.0134, time = 2.1957 s.
# Epoch 101: Loss = 0.0155, time = 2.0494 s.
# Epoch 102: Loss = 0.0160, time = 2.0479 s.
# Epoch 103: Loss = 0.0148, time = 2.0632 s.
# Epoch 104: Loss = 0.0124, time = 2.1984 s.
# Epoch 105: Loss = 0.0102, time = 2.0571 s.
# Epoch 106: Loss = 0.0095, time = 2.0496 s.
# Epoch 107: Loss = 0.0098, time = 2.0500 s.
# Epoch 108: Loss = 0.0106, time = 2.0533 s.
# Epoch 109: Loss = 0.0114, time = 2.1959 s.
# Epoch 110: Loss = 0.0120, time = 2.0527 s.
# Epoch 111: Loss = 0.0119, time = 2.0493 s.
# Epoch 112: Loss = 0.0113, time = 2.0560 s.
# Epoch 113: Loss = 0.0103, time = 2.0546 s.
# Epoch 114: Loss = 0.0096, time = 2.1974 s.
# Epoch 115: Loss = 0.0093, time = 2.0536 s.
# Epoch 116: Loss = 0.0095, time = 2.0582 s.
# Epoch 117: Loss = 0.0099, time = 2.0527 s.
# Epoch 118: Loss = 0.0103, time = 2.0483 s.
# Epoch 119: Loss = 0.0104, time = 2.1910 s.
# Epoch 120: Loss = 0.0102, time = 2.0540 s.
# Epoch 121: Loss = 0.0098, time = 2.0500 s.
# Epoch 122: Loss = 0.0094, time = 2.0568 s.
# Epoch 123: Loss = 0.0092, time = 2.1923 s.
# Epoch 124: Loss = 0.0093, time = 2.0495 s.
# Epoch 125: Loss = 0.0095, time = 2.0514 s.
# Epoch 126: Loss = 0.0097, time = 2.0458 s.
# Epoch 127: Loss = 0.0097, time = 2.0472 s.
# Epoch 128: Loss = 0.0097, time = 2.1912 s.
# Epoch 129: Loss = 0.0095, time = 2.0477 s.
# Epoch 130: Loss = 0.0093, time = 2.0528 s.
# Epoch 131: Loss = 0.0092, time = 2.0459 s.
# Epoch 132: Loss = 0.0092, time = 2.1993 s.
# Epoch 133: Loss = 0.0093, time = 2.0538 s.
# Epoch 134: Loss = 0.0094, time = 2.0521 s.
# Epoch 135: Loss = 0.0094, time = 2.0459 s.
# Epoch 136: Loss = 0.0094, time = 2.0501 s.
# Epoch 137: Loss = 0.0093, time = 2.1941 s.
# Epoch 138: Loss = 0.0092, time = 2.0533 s.
# Epoch 139: Loss = 0.0092, time = 2.0543 s.
# Epoch 140: Loss = 0.0092, time = 2.0535 s.
# Epoch 141: Loss = 0.0093, time = 2.0558 s.
# Epoch 142: Loss = 0.0093, time = 2.1832 s.
# Epoch 143: Loss = 0.0093, time = 2.0538 s.
# Epoch 144: Loss = 0.0093, time = 2.0555 s.
# Epoch 145: Loss = 0.0092, time = 2.0481 s.
# Epoch 146: Loss = 0.0092, time = 2.1895 s.
# Epoch 147: Loss = 0.0092, time = 2.0605 s.
# Epoch 148: Loss = 0.0092, time = 2.0500 s.
# Epoch 149: Loss = 0.0092, time = 2.0505 s.
# Epoch 150: Loss = 0.0092, time = 2.0518 s.
# Epoch 151: Loss = 0.0092, time = 2.1962 s.
# Epoch 152: Loss = 0.0092, time = 2.0499 s.
# Epoch 153: Loss = 0.0092, time = 2.0564 s.
# Epoch 154: Loss = 0.0092, time = 2.0427 s.
# Epoch 155: Loss = 0.0092, time = 2.1956 s.
# Epoch 156: Loss = 0.0092, time = 2.0564 s.
# Epoch 157: Loss = 0.0092, time = 2.0514 s.
# Epoch 158: Loss = 0.0092, time = 2.0461 s.
# Epoch 159: Loss = 0.0092, time = 2.0537 s.
# Epoch 160: Loss = 0.0092, time = 2.1938 s.
# Epoch 161: Loss = 0.0092, time = 2.0540 s.
# Epoch 162: Loss = 0.0092, time = 2.0487 s.
# Epoch 163: Loss = 0.0092, time = 2.0506 s.
# Epoch 164: Loss = 0.0092, time = 2.1886 s.
# Epoch 165: Loss = 0.0092, time = 2.0502 s.
# Epoch 166: Loss = 0.0092, time = 2.0526 s.
# Epoch 167: Loss = 0.0092, time = 2.0483 s.
# Epoch 168: Loss = 0.0092, time = 2.0439 s.
# Epoch 169: Loss = 0.0092, time = 2.1836 s.
# Epoch 170: Loss = 0.0092, time = 2.0471 s.
# Epoch 171: Loss = 0.0092, time = 2.0505 s.
# Epoch 172: Loss = 0.0092, time = 2.0669 s.
# Epoch 173: Loss = 0.0092, time = 2.2124 s.
# Epoch 174: Loss = 0.0092, time = 2.0581 s.
# Epoch 175: Loss = 0.0092, time = 2.0529 s.
# Epoch 176: Loss = 0.0091, time = 2.0454 s.
# Epoch 177: Loss = 0.0091, time = 2.1908 s.
# Epoch 178: Loss = 0.0091, time = 2.0461 s.
# Epoch 179: Loss = 0.0091, time = 2.0431 s.
# Epoch 180: Loss = 0.0091, time = 2.0498 s.
# Epoch 181: Loss = 0.0091, time = 2.0497 s.
# Epoch 182: Loss = 0.0091, time = 2.1965 s.
# Epoch 183: Loss = 0.0091, time = 2.0442 s.
# Epoch 184: Loss = 0.0091, time = 2.0522 s.
# Epoch 185: Loss = 0.0091, time = 2.0494 s.
# Epoch 186: Loss = 0.0091, time = 2.0521 s.
# Epoch 187: Loss = 0.0091, time = 2.1827 s.
# Epoch 188: Loss = 0.0091, time = 2.0473 s.
# Epoch 189: Loss = 0.0091, time = 2.0457 s.
# Epoch 190: Loss = 0.0091, time = 2.0504 s.
# Epoch 191: Loss = 0.0091, time = 2.0482 s.
# Epoch 192: Loss = 0.0091, time = 2.1861 s.
# Epoch 193: Loss = 0.0091, time = 2.0454 s.
# Epoch 194: Loss = 0.0091, time = 2.0440 s.
# Epoch 195: Loss = 0.0091, time = 2.0499 s.
# Epoch 196: Loss = 0.0091, time = 2.1826 s.
# Epoch 197: Loss = 0.0091, time = 2.0444 s.
# Epoch 198: Loss = 0.0091, time = 2.0424 s.
# Epoch 199: Loss = 0.0091, time = 2.0489 s.

# %%
x_pred = odeint(lambda t, x: ode_model(t,x,lam_func), x0, t_span,method='rk4')

# %%
plt.plot(x_true[200:300])

# %%
fig, ax = plt.subplots(1,1, figsize=(8,5))


ax.plot(x_pred.squeeze().detach().cpu().numpy(), linestyle='--',c='red', label='prediction')
ax.plot(x_true,label='true')
ax.set_xlabel(r'$t$',size=10)
ax.set_ylabel(r'$x(\tau=\infty)$',size=15)
ax.set_title(r"Steady state of $x$ for $\lambda_t$", size=20)
ax.grid(True)
ax.legend()
plt.savefig(f"epochs_{n_epochs}_scaled_data.png")
plt.show()

# %% [markdown]
# ### save results

# %%
f_cpu = f.to('cpu')
g_cpu = g.to('cpu')
ode_model_cpu = ODEModel(f_cpu, g_cpu)

# %%
save_path = f"full_gd_lr_01_epoch_{n_epochs}_scaled_data.pt"

torch.save({"f_state_dict": f_cpu.state_dict(),
           "g_state_dict": g_cpu.state_dict(),
           "ode_model_state_dict": ode_model_cpu.state_dict()}, save_path)

f.to(device)
g.to(device)
# Out:
# GTerm(
#   (network): Sequential(
#     (0): Linear(in_features=2, out_features=4, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=4, out_features=1, bias=True)
#     (3): Tanh()
#   )
# )

# %%
g
# Out:
# GTerm(
#   (network): Sequential(
#     (0): Linear(in_features=2, out_features=4, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=4, out_features=1, bias=True)
#     (3): Tanh()
#   )
# )

# %%
def g_true(x,lam):
    return (1/x)*(lam/x+1)

# %%
g.eval()

g_out = []
g_true_out = []
for idx in range(len(x_true)):
    xi = x_true[idx]
    xi = torch.tensor([[xi]],dtype =torch.float32,device=device)

    lami = lam_vals[idx]
    lami = torch.tensor([[lami]],dtype=torch.float32,device=device)

    with torch.no_grad():
        g_out.append(g(xi,lami).detach().cpu().numpy())

    g_true_out.append(g_true(xi,lami).detach().cpu().numpy())

# %%
g_out = np.array(g_out).reshape(-1)

# %%
g_true_out = np.array(g_true_out).reshape(-1)
g_true_out.shape
# Out:
# (1000,)

# %%
fig, ax = plt.subplots(1,1,figsize=(8,5))

ax.plot(g_true_out,c='black', label=r'true $g$')
ax.plot(t_span.detach().cpu().numpy(),g_out,c='red', linestyle="--", label=r"$g$ node prediction")
ax.plot(x_true.squeeze().detach().cpu().numpy(),label=r'true simulated $x(\tau=\infty)$')
# ax.plot(x_pred.squeeze().detach().cpu().numpy(), linestyle='--',c='red', label='prediction')

ax.set_xlabel(r'$t$',size=10)
ax.set_ylabel(r'$x(\tau=\infty)$',size=15)
ax.set_title(r"Steady state of $x$ for $\lambda_t$", size=20)
ax.grid(True)
ax.legend()
plt.savefig(f"epochs_{n_epochs}.png")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fig, ax = plt.subplots(1,1,figsize=(8,5))
#       3 ax.plot(g_true_out,c='black', label=r'true $g$')
#       4 ax.plot(t_span.detach().cpu().numpy(),g_out,c='red', linestyle="--", label=r"$g$ node prediction")
#
# NameError: name 'plt' is not defined
